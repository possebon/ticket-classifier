# %%
import pandas as pd
import json

with open('data/preprocess/tickets_labeled.json') as f:  
    data = json.load(f)
    df=pd.DataFrame(data)

# %%
df
# Out:
#       ticket_id  article_id  \
# 0             1           1
# 1             3           3
# 2             4           7
# 3             5           8
# 4             6           9
# ...         ...         ...
# 8257       8454       30756
# 8258       8455       30762
# 8259       8456       30769
# 8260       8457       30772
# 8261       8458       30779
#
#                                         article_subject  \
# 0     Funcionamento incompleto http://cliente.havan....
# 1                           Queda das ligações_01/03/16
# 2                                                 teste
# 3                            verificar bloqueio na rede
# 4                         Pastas excluídas que retornam
# ...                                                 ...
# 8257                        Criação de perfil para VPN.
# 8258  [Ticket#2021051784000012] Novo servidor TS ina...
# 8259              Changes to YouTube’s Terms of Service
# ...
